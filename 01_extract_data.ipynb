# %% [markdown]
# ### Proyecto final - Data Analyst - GreenShark
#
# #### Erick Macías
#
# 1. **El problema**: actualmente es costoso y poco accesible encontrar información de ventas a nivel de establecimientos en una zona geográfica dada. Dicha información permite entender la dinámica de un sector en específico a nivel de establecimientos, y permite oprimizar la toma de decisiones que comunmente se busca con un estudio de mercado, los cuales sulen ser costos y tardados.
#
# 2. **El objetivo**: estimar las ventas de los establecimientos dedicados a drindar el servicio de acondicionamiento físico (gimnasios)  en la Benito Juárez. Se toma este caso particular, suponiendo que el uso del análisis, en este caso, será para evaluar la viabilidad de abrir un gimnasio en en esta delegación, tomando como principal indicador la magnitud de sus ingresos. Si es posible lograr este objetivo, este análisis puede ser herramienta útil para replicarse a cualquier industria que se quiere investigar y tomar decisiones optimas de manera más rápida y eficiente.

# %% [markdown]
# #### En este notbook vamos a  preparar las diferentes bases que combinaremos para hacer la estimación de las ventas para los establecimientos del sector elegido.
#
# *Primero.* Se utilizará la **API del INEGI - DENUE** para extraer los datos de los establecimientos dedicados a brindar el servicio de GYM. La API regresa los datos en formato json por lo que hay que estructurar dicha data.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Vamos a guardar el token en una variable

token_inegi = 'a3b8464e-1fd8-449c-a5f8-4410c02ec510'

# %%
#En esta variable podemos nombrar el nombre del sector que se quiere analizar segun el scian, en nuestro caso es el:
#713943 Centros de acondicionamiento físico del sector privado
#Se puede consultar todo el catalogo de clasificación de establecimientos en http://www.beta.inegi.org.mx/app/scian/

scian_nombre = '"Centros de acondicionamiento físico del sector privado"'
num_entidad = '09' #Corresponde a la CDMX

# %%
url_api_gym = 'http://www3.inegi.org.mx/sistemas/api/denue/v1/consulta/buscarEntidad/'+scian_nombre+'/'+num_entidad+'/1/11000/'+token_inegi

# %%
url_api_gym
# Out:
# 'http://www3.inegi.org.mx/sistemas/api/denue/v1/consulta/buscarEntidad/"Centros de acondicionamiento físico del sector privado"/09/1/11000/a3b8464e-1fd8-449c-a5f8-4410c02ec510'

# %%
#Se aplica el método get a la API del DENUE y se lee el archivo json que regresa.
r = requests.get(url_api_gym)
x = r.json()

# %%
#Vemos como se ve el json del DENUE
x
# Out:
# [{'CP': '11550',
#   'Calle': 'ANATOLE FRANCE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'POLANCO REFORMA',
#   'Correo_e': 'INFO@EVOLUTIONPILATES.COM.MX',
#   'Estrato': '11 a 30 personas',
#   'Id': '689998',
#   'Latitud': '19.43242053',
#   'Longitud': '-99.19751597',
#   'Nombre': '+EVOLUTION PILATES FITNNESS',
#   'Num_Exterior': '129',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.EVOLUTIONPILATES.COM.MX',
#   'Telefono': '5552818011',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'MIGUEL HIDALGO, Miguel Hidalgo, CIUDAD DE MÉXICO'},
#  {'CP': '07080',
#   'Calle': 'CABO VERDE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'GABRIEL HERNANDEZ',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '752673',
#   'Latitud': '19.49710213',
#   'Longitud': '-99.09947190',
#   'Nombre': '4LMENTS',
#   'Num_Exterior': '18',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '06170',
#   'Calle': 'ALFONSO REYES',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'HIPÓDROMO CONDESA',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '867230',
#   'Latitud': '19.41105369',
#   'Longitud': '-99.18176246',
#   'Nombre': '4U GYM',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '4UGYM.COM.MX',
#   'Telefono': '5552712042',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '03910',
#   'Calle': 'INSURGENTES SUR',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN JOSÉ INSURGENTES',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '6785444',
#   'Latitud': '19.36301818',
#   'Longitud': '-99.18258457',
#   'Nombre': '8W BARRANCA DEL MUERTO',
#   'Num_Exterior': '1647',
#   'Num_Interior': '',
#   'Razon_social': 'OCHO SEMANAS I SAPI SA DE CV',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO'},
#  {'CP': '06100',
#   'Calle': '3 SUR (AVENIDA BAJA CALIFORNIA)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'HIPÓDROMO',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '6734479',
#   'Latitud': '19.40587201',
#   'Longitud': '-99.17085291',
#   'Nombre': '8W CONDESA',
#   'Num_Exterior': '261',
#   'Num_Interior': '',
#   'Razon_social': 'OCHO SEMANAS I SAPI SA DE CV',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'EJE VIAL',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '11000',
#   'Calle': 'PASEO DE LAS PALMAS',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LOMAS DE CHAPULTEPEC I SECCIÓN',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '6726682',
#   'Latitud': '19.42612237',
#   'Longitud': '-99.22182478',
#   'Nombre': '8W PALMAS',
#   'Num_Exterior': '1065',
#   'Num_Interior': '',
#   'Razon_social': 'OCHO SEMANAS I SAPI SA DE CV',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'MIGUEL HIDALGO, Miguel Hidalgo, CIUDAD DE MÉXICO'},
#  {'CP': '6700',
#   'Calle': 'TONALÁ',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'ROMA NORTE',
#   'Correo_e': '',
#   'Estrato': '11 a 30 personas',
#   'Id': '6785440',
#   'Latitud': '19.42105596',
#   'Longitud': '-99.16331559',
#   'Nombre': '8W ROMA',
#   'Num_Exterior': '15',
#   'Num_Interior': '',
#   'Razon_social': 'OCHO SEMANAS I SAPI SA DE CV',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '5300',
#   'Calle': 'VASCO DE QUIROGA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LOMAS DE SANTA FÉ',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '6706653',
#   'Latitud': '19.36135471',
#   'Longitud': '-99.27869077',
#   'Nombre': '8W SANTA FE',
#   'Num_Exterior': '3900',
#   'Num_Interior': '',
#   'Razon_social': 'OCHO SEMANAS I SAPI SA DE CV',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'PROLONGACIÓN',
#   'Ubicacion': 'CUAJIMALPA DE MORELOS, Cuajimalpa de Morelos, CIUDAD DE MÉXICO'},
#  {'CP': '09820',
#   'Calle': 'PRIVADA ERMITA IZTAPALAPA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTA ISABEL INDUSTRIAL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '714415',
#   'Latitud': '19.35158364',
#   'Longitud': '-99.10105980',
#   'Nombre': 'ABC GIMNASIO',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '12000',
#   'Calle': 'GUANAJUATO ORIENTE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LA CONCEPCIÓN',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '949905',
#   'Latitud': '19.19083131',
#   'Longitud': '-99.02051168',
#   'Nombre': 'ACADEMIA BODY FACTORY, CLASES DE ZUMBA',
#   'Num_Exterior': '20',
#   'Num_Interior': '2',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'VILLA MILPA ALTA, Milpa Alta, CIUDAD DE MÉXICO'},
#  {'CP': '09609',
#   'Calle': 'HIGUERILLA (PALMAR)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': '2DA AMPLIACIÓN SANTIAGO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '817682',
#   'Latitud': '19.34310020',
#   'Longitud': '-99.00828161',
#   'Nombre': 'ACADEMIA BRILLER',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '13300',
#   'Calle': 'NINGUNO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PUEBLO SANTIAGO ZAPOTITLÁN',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '943517',
#   'Latitud': '19.29703244',
#   'Longitud': '-99.03302391',
#   'Nombre': 'ACADEMIA DE ARTE DAJHOZ',
#   'Num_Exterior': '6594',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CERRADA',
#   'Ubicacion': 'TLÁHUAC, Tláhuac, CIUDAD DE MÉXICO'},
#  {'CP': '14039',
#   'Calle': 'LAS FUENTES',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'AMPLIACION ISIDRO FABELA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '857865',
#   'Latitud': '19.29718097',
#   'Longitud': '-99.16857954',
#   'Nombre': 'ACADEMIA DE BAILE ARTE EN MOVIMIENTO',
#   'Num_Exterior': '3',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLALPAN, Tlalpan, CIUDAD DE MÉXICO'},
#  {'CP': '06350',
#   'Calle': 'PUENTE DE ALVARADO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'BUENAVISTA',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '877522',
#   'Latitud': '19.43929277',
#   'Longitud': '-99.15354875',
#   'Nombre': 'ACADEMIA DE BAILE BALDERAS',
#   'Num_Exterior': '71',
#   'Num_Interior': '101',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555355799',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '09620',
#   'Calle': '15 DE SEPTIEMBRE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LOMAS DE ZARAGOZA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '806543',
#   'Latitud': '19.35164828',
#   'Longitud': '-98.99617783',
#   'Nombre': 'ACADEMIA DE BAILE BLACK DANCE',
#   'Num_Exterior': '27',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '08500',
#   'Calle': 'SUR 12',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'AGRICOLA ORIENTAL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '710333',
#   'Latitud': '19.39716862',
#   'Longitud': '-99.07158517',
#   'Nombre': 'ACADEMIA DE BAILE BLACK MOON',
#   'Num_Exterior': '274',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557160217',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTACALCO, Iztacalco, CIUDAD DE MÉXICO'},
#  {'CP': '09760',
#   'Calle': 'ARROYO EL MORTERO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CONSEJO AGRARISTA MEXICANO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '724584',
#   'Latitud': '19.32784939',
#   'Longitud': '-99.05959832',
#   'Nombre': 'ACADEMIA DE BAILE BOONE DANCE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '09970',
#   'Calle': 'EMILIANO ZAPATA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'VALLE DE SAN LORENZO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '841437',
#   'Latitud': '19.29694538',
#   'Longitud': '-99.07547322',
#   'Nombre': 'ACADEMIA DE BAILE CLUB FARAÓN',
#   'Num_Exterior': '229',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Semifijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '13220',
#   'Calle': 'TLÁHUAC',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LA NOPALERA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '945197',
#   'Latitud': '19.30091443',
#   'Longitud': '-99.05123013',
#   'Nombre': 'ACADEMIA DE BAILE COMPLEXIONS',
#   'Num_Exterior': '5905',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'TLÁHUAC, Tláhuac, CIUDAD DE MÉXICO'},
#  {'CP': '09620',
#   'Calle': 'CARRANZA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LOMAS DE ZARAGOZA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '806471',
#   'Latitud': '19.35322450',
#   'Longitud': '-98.99579295',
#   'Nombre': 'ACADEMIA DE BAILE ELEGANCE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5558555692',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '09609',
#   'Calle': 'LEONA VICARIO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SEGUNDA AMPLIACIÓN SANTIAGO ACAHUALTEPEC',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '831664',
#   'Latitud': '19.34632299',
#   'Longitud': '-99.01352795',
#   'Nombre': 'ACADEMIA DE BAILE JAMA TOGA',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '07230',
#   'Calle': 'ANTONIO CASO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'ZONA ESCOLAR',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '637182',
#   'Latitud': '19.54071030',
#   'Longitud': '-99.15033387',
#   'Nombre': 'ACADEMIA DE BAILE LALOS DANCE STAR',
#   'Num_Exterior': '8',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5534680056',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '07730',
#   'Calle': '5 NORTE (MONTEVIDEO)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN BARTOLO ATEPEHUACAN',
#   'Correo_e': 'ALFREDO_YEPA@HOTMAIL.COM',
#   'Estrato': '6 a 10 personas',
#   'Id': '673207',
#   'Latitud': '19.49271597',
#   'Longitud': '-99.14357864',
#   'Nombre': 'ACADEMIA DE BAILE RANDY´S',
#   'Num_Exterior': '590',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5553687757',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'EJE VIAL',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '08200',
#   'Calle': 'CALZADA DE TLALPAN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'VIADUCTO PIEDAD',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '704476',
#   'Latitud': '19.40084805',
#   'Longitud': '-99.13662668',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '450',
#   'Num_Interior': '1',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.PHOYDSTUDIO.COM.MX',
#   'Telefono': '5555555190',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTACALCO, Iztacalco, CIUDAD DE MÉXICO'},
#  {'CP': '12100',
#   'Calle': 'JOSÉ MARÍA MORELOS',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN ANTONIO TECOMITL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '948977',
#   'Latitud': '19.22110004',
#   'Longitud': '-98.99380508',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'SAN ANTONIO TECÓMITL, Milpa Alta, CIUDAD DE MÉXICO'},
#  {'CP': '07230',
#   'Calle': 'FRANCISCO VILLA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'ZONA ESCOLAR',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '670685',
#   'Latitud': '19.54318014',
#   'Longitud': '-99.14883758',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '1',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '07420',
#   'Calle': 'INGENIERO EDUARDO MOLINA EJE 3 ORIENTE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'NUEVA ATZACOALCO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '764181',
#   'Latitud': '19.50531604',
#   'Longitud': '-99.08617762',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '2227',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '09060',
#   'Calle': 'EJE 3 ORIENTE (AVENIDA 5)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'ESCUADRÓN 201',
#   'Correo_e': 'JUST_DANCE20@HOTMAIL.COM',
#   'Estrato': '0 a 5 personas',
#   'Id': '713701',
#   'Latitud': '19.36139587',
#   'Longitud': '-99.11041041',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '152',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556467400',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'EJE VIAL',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '13280',
#   'Calle': 'EL MURCIÉLAGO (GRANJERO)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'AGRICOLA METROPOLITANA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '945683',
#   'Latitud': '19.29123518',
#   'Longitud': '-99.04957112',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLÁHUAC, Tláhuac, CIUDAD DE MÉXICO'},
#  {'CP': '02240',
#   'Calle': 'CAMPO ALAZÁN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN ANDRÉS',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '648308',
#   'Latitud': '19.49202966',
#   'Longitud': '-99.18623456',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '144',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5553827573',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'AZCAPOTZALCO, Azcapotzalco, CIUDAD DE MÉXICO'},
#  {'CP': '07840',
#   'Calle': '3 NORTE (NOÉ)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'GUADALUPE TEPEYAC',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '785312',
#   'Latitud': '19.46700926',
#   'Longitud': '-99.12173918',
#   'Nombre': 'ACADEMIA DE BAILE SIN NOMBRE',
#   'Num_Exterior': '43',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5585894350',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'EJE VIAL',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '08000',
#   'Calle': 'SUR 167',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'GABRIEL RAMOS MILLÁN SECCIÓN BRAMADERO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '708199',
#   'Latitud': '19.39018014',
#   'Longitud': '-99.09402257',
#   'Nombre': 'ACADEMIA DE BAILE STAR DANCE',
#   'Num_Exterior': '1912',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTACALCO, Iztacalco, CIUDAD DE MÉXICO'},
#  {'CP': '07510',
#   'Calle': 'DOLORES HIDALGO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN FELIPE DE JESÚS',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '809301',
#   'Latitud': '19.49207304',
#   'Longitud': '-99.07456406',
#   'Nombre': 'ACADEMIA DE BAILE STOP DANCE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557674406',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '09700',
#   'Calle': 'VILLA FRUELA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'DESARROLLO URBANO QUETZALCOATL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '844040',
#   'Latitud': '19.32544880',
#   'Longitud': '-99.03788169',
#   'Nombre': 'ACADEMIA DE BAILE SULLY',
#   'Num_Exterior': '65',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '06030',
#   'Calle': 'HIDALGO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'TABACALERA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1021654',
#   'Latitud': '19.43749486',
#   'Longitud': '-99.14794537',
#   'Nombre': 'ACADEMIA DE BAILE TERESA',
#   'Num_Exterior': '118',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555109574',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '13270',
#   'Calle': 'ABULÓN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'DEL MAR',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1049365',
#   'Latitud': '19.28742925',
#   'Longitud': '-99.05695351',
#   'Nombre': 'ACADEMIA DE BAILE Y ZUMBA FITNESS',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5521607980',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLÁHUAC, Tláhuac, CIUDAD DE MÉXICO'},
#  {'CP': '16300',
#   'Calle': 'MIGUEL HIDALGO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN LUCAS XOCHIMANCA',
#   'Correo_e': 'ACADEMIADEBAILEZL2@HOTMAIL.COM',
#   'Estrato': '0 a 5 personas',
#   'Id': '941979',
#   'Latitud': '19.23540217',
#   'Longitud': '-99.11990297',
#   'Nombre': 'ACADEMIA DE BAILE ZL2',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'XOCHIMILCO, Xochimilco, CIUDAD DE MÉXICO'},
#  {'CP': '04890',
#   'Calle': '1 ORIENTE (AVENIDA CANAL DE MIRAMONTES)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'JARDINES DE COYOACÁN',
#   'Correo_e': 'BYKX@HOTMAIL.COM',
#   'Estrato': '0 a 5 personas',
#   'Id': '982508',
#   'Latitud': '19.31535630',
#   'Longitud': '-99.12478913',
#   'Nombre': 'ACADEMIA DE BAILE: STILO DANCE',
#   'Num_Exterior': '2783',
#   'Num_Interior': '108',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'EJE VIAL',
#   'Ubicacion': 'COYOACÁN, Coyoacán, CIUDAD DE MÉXICO'},
#  {'CP': '10200',
#   'Calle': 'HÉROES DE PADIERNA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN JERÓNIMO LÍDICE',
#   'Correo_e': 'SANJERÓNIMO@BABYBALLET.MX',
#   'Estrato': '11 a 30 personas',
#   'Id': '928995',
#   'Latitud': '19.32330068',
#   'Longitud': '-99.22322464',
#   'Nombre': 'ACADEMIA DE DANZA BABY BALLET',
#   'Num_Exterior': '132',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.BABYBALLET.MX',
#   'Telefono': '5555951297',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '07300',
#   'Calle': 'LINDAVISTA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LINDAVISTA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '749430',
#   'Latitud': '19.49164021',
#   'Longitud': '-99.12488041',
#   'Nombre': 'ACADEMIA DE DANZA BAJAY BALLET',
#   'Num_Exterior': '169',
#   'Num_Interior': '',
#   'Razon_social': 'BABY BALLET MARSET',
#   'Sitio_internet': 'WWW.BABYBALLETWARBET.COM',
#   'Telefono': '5555635364',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '09609',
#   'Calle': 'DE LAS TORRES',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': '2DA AMPLIACIÓN SANTIAGO ACAHUALTEPEC',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '732310',
#   'Latitud': '19.35080608',
#   'Longitud': '-99.01159117',
#   'Nombre': 'ACADEMIA DE DEFENSA PERSONAL',
#   'Num_Exterior': '26',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '07510',
#   'Calle': 'CHOLULA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN FELIPE DE JESÚS',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '679765',
#   'Latitud': '19.49388937',
#   'Longitud': '-99.07301472',
#   'Nombre': 'ACADEMIA DE GIMNASIA OLIMPICA GYM KID',
#   'Num_Exterior': '1696',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '11200',
#   'Calle': 'CERRADA CALZADA INGENIEROS MILITARES',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LOMAS DE SOTELO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '689046',
#   'Latitud': '19.44679723',
#   'Longitud': '-99.21709316',
#   'Nombre': 'ACADEMIA DE TENIS MVPTENIS',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.MVPTENIS.COM',
#   'Telefono': '5553953817',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'MIGUEL HIDALGO, Miguel Hidalgo, CIUDAD DE MÉXICO'},
#  {'CP': '07200',
#   'Calle': 'FRANCISCO VILLA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CASTILLO CHICO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '671081',
#   'Latitud': '19.54097966',
#   'Longitud': '-99.13929078',
#   'Nombre': 'ACADEMIA DE ZUMBA SIN NOMBRE',
#   'Num_Exterior': '16',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '08500',
#   'Calle': 'ORIENTE 245',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'AGRICOLA ORIENTAL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '812127',
#   'Latitud': '19.39893670',
#   'Longitud': '-99.06973423',
#   'Nombre': 'ACADEMIA DE ZUMBA SIN NOMBRE',
#   'Num_Exterior': '143',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555581462',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTACALCO, Iztacalco, CIUDAD DE MÉXICO'},
#  {'CP': '08500',
#   'Calle': 'ORIENTE 243-B',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'AGRICOLA ORIENTAL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '710321',
#   'Latitud': '19.39892558',
#   'Longitud': '-99.07029412',
#   'Nombre': 'ACADEMIA ESTUDIO BAILES PARA XVAÑOS',
#   'Num_Exterior': '46',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5565522209',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTACALCO, Iztacalco, CIUDAD DE MÉXICO'},
#  {'CP': '14100',
#   'Calle': 'HALACHO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PEDREGAL DE SAN NICOLÁS TERCERA SECCIÓN',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '849582',
#   'Latitud': '19.28662064',
#   'Longitud': '-99.23570198',
#   'Nombre': 'ACADEMIA FITNESS DANCE',
#   'Num_Exterior': '2',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLALPAN, Tlalpan, CIUDAD DE MÉXICO'},
#  {'CP': '01650',
#   'Calle': 'TAPUYAS',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'TLACUITLAPA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '925772',
#   'Latitud': '19.35432743',
#   'Longitud': '-99.23573713',
#   'Nombre': 'ACADEMIA NICKTDANCE',
#   'Num_Exterior': '16',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'ÁLVARO OBREGÓN, Álvaro Obregón, CIUDAD DE MÉXICO'},
#  {'CP': '09770',
#   'Calle': 'RÍO CONSULADO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PUENTE BLANCO',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '724779',
#   'Latitud': '19.32780613',
#   'Longitud': '-99.06572680',
#   'Nombre': 'ACADEMIA PROFESIONAL DE ARTE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556905488',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '07979',
#   'Calle': '608',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'UNIDAD HABITACIONAL SAN JUAN DE ARAGÓN CUARTA Y QUINTA SECCIÓN',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '678923',
#   'Latitud': '19.46046924',
#   'Longitud': '-99.06482474',
#   'Nombre': 'ACADEMIA PROFESIONAL DE DANZA Y ARTES CREATIVAS SIN NOMBRE',
#   'Num_Exterior': '297',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557839475',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '06010',
#   'Calle': 'VIZCAÍNAS',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CENTRO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1040267',
#   'Latitud': '19.42911370',
#   'Longitud': '-99.14226292',
#   'Nombre': 'ACADEMIA RENZO GRACIE',
#   'Num_Exterior': '13',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.RENZOGRACIEMEXICO.COM',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '13200',
#   'Calle': 'DON GIOVANI (NARDO)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'MIGUEL HIDALGO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '945356',
#   'Latitud': '19.29267154',
#   'Longitud': '-99.05019238',
#   'Nombre': 'ACADEMIA SIN NOMBRE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLÁHUAC, Tláhuac, CIUDAD DE MÉXICO'},
#  {'CP': '02730',
#   'Calle': 'FF. CC. NACIONALES DE MÉXICO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN FRANCISCO TETECALA',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '644650',
#   'Latitud': '19.47791156',
#   'Longitud': '-99.19018064',
#   'Nombre': 'ACADEMIA SIN NOMBRE',
#   'Num_Exterior': '434',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5565460423',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'AZCAPOTZALCO, Azcapotzalco, CIUDAD DE MÉXICO'},
#  {'CP': '07620',
#   'Calle': '20-A',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTA ROSA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '671806',
#   'Latitud': '19.52386247',
#   'Longitud': '-99.16686993',
#   'Nombre': 'ACADEMIA STAR DANCE',
#   'Num_Exterior': '4',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5529136856',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '06060',
#   'Calle': 'ARCOS DE BELÉN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'JUAREZ',
#   'Correo_e': 'THALIASACADEMIOA@LIVE.COM.MX',
#   'Estrato': '0 a 5 personas',
#   'Id': '1030720',
#   'Latitud': '19.42638704',
#   'Longitud': '-99.15222717',
#   'Nombre': 'ACADEMIA THALIAS',
#   'Num_Exterior': '67',
#   'Num_Interior': '1',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.ACADEMIATHALIAS.COM',
#   'Telefono': '5557090066',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '15900',
#   'Calle': 'FRAY SERVANDO TERESA DE MIER',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'JARDÍN BALBUENA',
#   'Correo_e': 'HALIARANDYS21@HOTMAIL.COM',
#   'Estrato': '0 a 5 personas',
#   'Id': '758284',
#   'Latitud': '19.41655219',
#   'Longitud': '-99.09957986',
#   'Nombre': 'ACADEMIAS RANDY',
#   'Num_Exterior': '1033',
#   'Num_Interior': '4',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557859108',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'VENUSTIANO CARRANZA, Venustiano Carranza, CIUDAD DE MÉXICO'},
#  {'CP': '09608',
#   'Calle': 'TLAQUILPA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTIAGO ACAHUALTEPEC',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '831019',
#   'Latitud': '19.35181960',
#   'Longitud': '-99.01177554',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICO BIO ZUMBA',
#   'Num_Exterior': '26',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '01840',
#   'Calle': 'LUIS ECHEVERRÍA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'TORRES DE POTRERO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '928291',
#   'Latitud': '19.32895951',
#   'Longitud': '-99.25539064',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICO FITNEEX',
#   'Num_Exterior': '4',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'ÁLVARO OBREGÓN, Álvaro Obregón, CIUDAD DE MÉXICO'},
#  {'CP': '01830',
#   'Calle': 'CERRADA FRAY BARTOLOMÉ DE LAS CASAS',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTA ROSA XOCHIAC',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '928683',
#   'Latitud': '19.32854099',
#   'Longitud': '-99.28502293',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICO FITNESS TAURUS',
#   'Num_Exterior': '65',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5558105156',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'ÁLVARO OBREGÓN, Álvaro Obregón, CIUDAD DE MÉXICO'},
#  {'CP': '10400',
#   'Calle': 'LUIS CABRERA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN JERÓNIMO ACULCO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1021212',
#   'Latitud': '19.32086886',
#   'Longitud': '-99.22713230',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICO FITSYS BALANCE',
#   'Num_Exterior': '240',
#   'Num_Interior': '',
#   'Razon_social': 'FITSYS BALANCE, S.A. DE C.V.',
#   'Sitio_internet': '',
#   'Telefono': '5559137136',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '01800',
#   'Calle': 'FRANCISCO I. MADERO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PUEBLO DE SAN BARTOLO AMEYALCO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '928807',
#   'Latitud': '19.33278803',
#   'Longitud': '-99.27461083',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICO OASIS FITNESS',
#   'Num_Exterior': '58',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'ÁLVARO OBREGÓN, Álvaro Obregón, CIUDAD DE MÉXICO'},
#  {'CP': '16200',
#   'Calle': 'EMILIANO ZAPATA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTIAGO TEPALCATLALPAN',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1032509',
#   'Latitud': '19.24920914',
#   'Longitud': '-99.11974160',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICO TEKNOFIT',
#   'Num_Exterior': '14',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5549959257',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'XOCHIMILCO, Xochimilco, CIUDAD DE MÉXICO'},
#  {'CP': '09700',
#   'Calle': 'VILLA HOZ',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'DESARROLLO URBANO QUETZALCOATL',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '737036',
#   'Latitud': '19.32925233',
#   'Longitud': '-99.04867503',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICO XPLOSIVE DANCE',
#   'Num_Exterior': '35',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '09520',
#   'Calle': 'YUCATÁN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN SEBASTIÁN TECOLOXTITLAN',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '825123',
#   'Latitud': '19.36070199',
#   'Longitud': '-99.01968941',
#   'Nombre': 'ACONDICIONAMIENTO FISICO ZUMBA SANDY',
#   'Num_Exterior': '5',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '04470',
#   'Calle': 'RETORNO 35',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PRESIDENTES EJIDAES',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '979383',
#   'Latitud': '19.32774063',
#   'Longitud': '-99.13257625',
#   'Nombre': 'ACONDICIONAMIENTO FÍSICOAH-KIN SISTEMA DE EJERCICIOS',
#   'Num_Exterior': '6',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'PRIVADA',
#   'Ubicacion': 'COYOACÁN, Coyoacán, CIUDAD DE MÉXICO'},
#  {'CP': '10200',
#   'Calle': 'PERIFÉRICO ADOLFO RUIZ CORTINES',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN JERÓNIMO LÍDICE',
#   'Correo_e': 'B.ORDONEZ@FISSIC.COM',
#   'Estrato': '11 a 30 personas',
#   'Id': '1060655',
#   'Latitud': '19.32446298',
#   'Longitud': '-99.21602886',
#   'Nombre': 'ACONDICIONAMIETNO FISSIC FITNESS',
#   'Num_Exterior': '3325',
#   'Num_Interior': '',
#   'Razon_social': 'SALUD Y FUERZA, S.A. DE C.V.',
#   'Sitio_internet': 'WWW.FISSIC.COM',
#   'Telefono': '5556683437',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'BOULEVARD',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '16018',
#   'Calle': 'PLAN DE MUYUGUARDA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN LORENZO LA CEBADA',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '986721',
#   'Latitud': '19.28177709',
#   'Longitud': '-99.11669069',
#   'Nombre': 'ACROPOLIS GYM',
#   'Num_Exterior': '206',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556765712',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'XOCHIMILCO, Xochimilco, CIUDAD DE MÉXICO'},
#  {'CP': '14420',
#   'Calle': 'INSURGENTES SUR',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTA ÚRSULA XITLA',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '915970',
#   'Latitud': '19.28800972',
#   'Longitud': '-99.17470548',
#   'Nombre': 'ACTION ENERGY',
#   'Num_Exterior': '3965',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALZADA',
#   'Ubicacion': 'TLALPAN, Tlalpan, CIUDAD DE MÉXICO'},
#  {'CP': '15410',
#   'Calle': 'BOLÍVARES',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SIMON BOLIVAR',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '648631',
#   'Latitud': '19.44695302',
#   'Longitud': '-99.09666897',
#   'Nombre': 'ACTIVACIÓN ZUMBA',
#   'Num_Exterior': '73',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'VENUSTIANO CARRANZA, Venustiano Carranza, CIUDAD DE MÉXICO'},
#  {'CP': '16310',
#   'Calle': 'EMILIANO ZAPATA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LOS REYES',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '880954',
#   'Latitud': '19.22568142',
#   'Longitud': '-98.96621142',
#   'Nombre': 'ACTIVATE MIX',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'SAN ANDRÉS MIXQUIC, Tláhuac, CIUDAD DE MÉXICO'},
#  {'CP': '09450',
#   'Calle': 'EJE 7 SUR (MUNICIPIO LIBRE)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'BANJIDAL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '6757835',
#   'Latitud': '19.36701554',
#   'Longitud': '-99.13666872',
#   'Nombre': 'ACTIVE FITNESS',
#   'Num_Exterior': '83',
#   'Num_Interior': '',
#   'Razon_social': 'GIMNASIO ACTIVO SA DE CV',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '03650',
#   'Calle': 'MATÍAS ROMERO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LETRAN VALLE',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '903660',
#   'Latitud': '19.37755534',
#   'Longitud': '-99.14891633',
#   'Nombre': 'ACTIVE FITNESS',
#   'Num_Exterior': '1889',
#   'Num_Interior': '',
#   'Razon_social': 'ACTIVE FITNESS, S.A. DE C.V.',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO'},
#  {'CP': '04600',
#   'Calle': 'POPOCATÉPETL',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PEDREGAL DE SANTA URSULA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '911039',
#   'Latitud': '19.31769528',
#   'Longitud': '-99.14623538',
#   'Nombre': 'ACTIVIDADES FISICULTURISTAS SIN NOMBRE',
#   'Num_Exterior': '511',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'COYOACÁN, Coyoacán, CIUDAD DE MÉXICO'},
#  {'CP': '07300',
#   'Calle': 'RIOBAMBA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LINDAVISTA',
#   'Correo_e': 'SQUASH_RIOBAMBA@HOTMAIL.COM',
#   'Estrato': '0 a 5 personas',
#   'Id': '652043',
#   'Latitud': '19.49551183',
#   'Longitud': '-99.12331601',
#   'Nombre': 'ACTIVIDADES RECREATIVAS SQUACH',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555866057',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '10400',
#   'Calle': 'TIHUATLÁN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN JERÓNIMO ACULCO',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '929058',
#   'Latitud': '19.31807023',
#   'Longitud': '-99.22229079',
#   'Nombre': 'ACUATIC FITNESS',
#   'Num_Exterior': '10',
#   'Num_Interior': '',
#   'Razon_social': 'ACUATIC FITNESS, S.A. DE C.V.',
#   'Sitio_internet': 'WWW.ACUATICFITNES.COM',
#   'Telefono': '62635135',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '04180',
#   'Calle': 'ESTRELLA CEFEIDA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PRADOS DE COYOACAN',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '911508',
#   'Latitud': '19.32025408',
#   'Longitud': '-99.13273789',
#   'Nombre': 'ADB ÁREA DE BAILE',
#   'Num_Exterior': '11',
#   'Num_Interior': '10',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556363211',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'COYOACÁN, Coyoacán, CIUDAD DE MÉXICO'},
#  {'CP': '06600',
#   'Calle': 'TOKIO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'JUÁREZ',
#   'Correo_e': 'ADICCTIONGYM@GMAIL.COM',
#   'Estrato': '11 a 30 personas',
#   'Id': '1028194',
#   'Latitud': '19.42355850',
#   'Longitud': '-99.17202657',
#   'Nombre': 'ADDICTION GYM',
#   'Num_Exterior': '52',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.ADICCTION.MX',
#   'Telefono': '5552074335',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '06060',
#   'Calle': 'REPÚBLICA DE URUGUAY',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CENTRO',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '1025424',
#   'Latitud': '19.43026537',
#   'Longitud': '-99.13479819',
#   'Nombre': 'AEROBICA FITNESS SCHOOL',
#   'Num_Exterior': '84',
#   'Num_Interior': '2',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555126824',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '09830',
#   'Calle': 'CERRO DE LA ESTRELLA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'EL MANTO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '723301',
#   'Latitud': '19.34743292',
#   'Longitud': '-99.08218961',
#   'Nombre': 'AEROBICOS SIN NOMBRE',
#   'Num_Exterior': '1',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '09970',
#   'Calle': 'RÍO FUERTE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'VALLE DE SAN LORENZO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '841449',
#   'Latitud': '19.29807705',
#   'Longitud': '-99.07657777',
#   'Nombre': 'AEROBICS SIN NOMBRE',
#   'Num_Exterior': '19',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '15660',
#   'Calle': 'XINANTÉCATL',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'ARENAL 3RA. SECCIÓN',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '664026',
#   'Latitud': '19.42794320',
#   'Longitud': '-99.05682414',
#   'Nombre': 'AEROBICS SIN NOMBRE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '0445540647684',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'VENUSTIANO CARRANZA, Venustiano Carranza, CIUDAD DE MÉXICO'},
#  {'CP': '09700',
#   'Calle': 'VILLA GONZALO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'DESARROLLO URBANO QUETZALCOATL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '844405',
#   'Latitud': '19.32342435',
#   'Longitud': '-99.03724067',
#   'Nombre': 'AEROBICS SIN NOMBRE',
#   'Num_Exterior': '51',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '09840',
#   'Calle': 'MOCTEZUMA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'AMPLIACIÓN LOS REYES',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '665056',
#   'Latitud': '19.34341756',
#   'Longitud': '-99.10281098',
#   'Nombre': 'AEROBICS SIN NOMBRE',
#   'Num_Exterior': '5',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556320435',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '09609',
#   'Calle': 'SAUCE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'AMPLIACIÓN SANTIAGO',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '817566',
#   'Latitud': '19.34496196',
#   'Longitud': '-99.00899023',
#   'Nombre': 'AEROBICS Y RUMBA SIN NOMBRE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '09700',
#   'Calle': 'CERRO DEL MIRADOR',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'BUENAVISTA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '844340',
#   'Latitud': '19.32558018',
#   'Longitud': '-99.02750170',
#   'Nombre': 'AEROBICS Y ZOOMBA STAR FITNESS',
#   'Num_Exterior': '1',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '14700',
#   'Calle': 'MARIANO MATAMOROS',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
# ...
#   'Telefono': '5566502894',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'MIGUEL HIDALGO, Miguel Hidalgo, CIUDAD DE MÉXICO'},
#  {'CP': '09640',
#   'Calle': 'CARLOS HANK GONZÁLEZ',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'XALPA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '732676',
#   'Latitud': '19.34311733',
#   'Longitud': '-99.00866756',
#   'Nombre': 'GIMNASIO MAXIMUS GYM',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '07530',
#   'Calle': 'CAMINO ESFUERZO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CAMPESTRE ARAGÓN',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '813215',
#   'Latitud': '19.48010852',
#   'Longitud': '-99.08010010',
#   'Nombre': 'GIMNASIO MEGA GYM',
#   'Num_Exterior': '122',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557530011',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '12100',
#   'Calle': 'PLAZA DE LA CORREGIDORA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CRUZTITLA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '949143',
#   'Latitud': '19.21696279',
#   'Longitud': '-98.99369832',
#   'Nombre': 'GIMNASIO MERRY DANCE',
#   'Num_Exterior': '3',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'SAN ANTONIO TECÓMITL, Milpa Alta, CIUDAD DE MÉXICO'},
#  {'CP': '09630',
#   'Calle': 'MÉXICO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN MIGUEL TEOTONGO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '821664',
#   'Latitud': '19.34492844',
#   'Longitud': '-98.99463191',
#   'Nombre': 'GIMNASIO MILKILOS',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5526356368',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '16210',
#   'Calle': 'REDENCIÓN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTIAGO TEPALCATLALPAN',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '996003',
#   'Latitud': '19.25455480',
#   'Longitud': '-99.11438280',
#   'Nombre': 'GIMNASIO MINOS FIT',
#   'Num_Exterior': '150',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556412223',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'XOCHIMILCO, Xochimilco, CIUDAD DE MÉXICO'},
#  {'CP': '13300',
#   'Calle': 'JUAN DE DIOS PEZA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTIAGO ZAPOTITLÁN',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1051959',
#   'Latitud': '19.30005731',
#   'Longitud': '-99.04141567',
#   'Nombre': 'GIMNASIO MISHO',
#   'Num_Exterior': '21',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLÁHUAC, Tláhuac, CIUDAD DE MÉXICO'},
#  {'CP': '09770',
#   'Calle': 'RÍO MISSISSIPI',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PUENTE BLANCO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '724525',
#   'Latitud': '19.32655135',
#   'Longitud': '-99.06266238',
#   'Nombre': 'GIMNASIO MONSTER´S GYM',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '08220',
#   'Calle': 'SANTIAGO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'BARRIO SAN PEDRO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '784840',
#   'Latitud': '19.39110926',
#   'Longitud': '-99.13112767',
#   'Nombre': 'GIMNASIO MR FORTIS',
#   'Num_Exterior': '249',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTACALCO, Iztacalco, CIUDAD DE MÉXICO'},
#  {'CP': '06900',
#   'Calle': 'NINGUNO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'UNIDAD NONOALCO TLATELOLCO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '857177',
#   'Latitud': '19.45404545',
#   'Longitud': '-99.14718868',
#   'Nombre': 'GIMNASIO MR MIKE',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557828114',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '09609',
#   'Calle': 'COLORÍN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SEGUNDA AMPLIACIÓN SANTIAGO ACAHUALTEPEC',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '818079',
#   'Latitud': '19.34597758',
#   'Longitud': '-99.00774869',
#   'Nombre': 'GIMNASIO MÚLTIPLE REBECA',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5554451069',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '14325',
#   'Calle': 'DON REFUGIO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'RINCONADA COAPA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '861433',
#   'Latitud': '19.29770099',
#   'Longitud': '-99.11904575',
#   'Nombre': 'GIMNASIO MUSCLE & FITNESS',
#   'Num_Exterior': '4',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLALPAN, Tlalpan, CIUDAD DE MÉXICO'},
#  {'CP': '10710',
#   'Calle': 'COAHUILA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SANTA TERESA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1023232',
#   'Latitud': '19.30880612',
#   'Longitud': '-99.23028695',
#   'Nombre': 'GIMNASIO MUSCLE HOUSE',
#   'Num_Exterior': '49',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '10580',
#   'Calle': 'J. MORENO SALIDO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'BARRANCA SECA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '929557',
#   'Latitud': '19.30564907',
#   'Longitud': '-99.23918996',
#   'Nombre': 'GIMNASIO MUSCLE XTREME',
#   'Num_Exterior': '89',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '10300',
#   'Calle': 'SAN JERÓNIMO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN BERNABÉ OCOTEPEC',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1025754',
#   'Latitud': '19.31101489',
#   'Longitud': '-99.25923534',
#   'Nombre': 'GIMNASIO NARCISSUS',
#   'Num_Exterior': '2629',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555857420',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '16800',
#   'Calle': 'MORELOS',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN MATEO XALPA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '942309',
#   'Latitud': '19.22953760',
#   'Longitud': '-99.11792641',
#   'Nombre': 'GIMNASIO NEW BODY',
#   'Num_Exterior': '175',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '0445536422240',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'XOCHIMILCO, Xochimilco, CIUDAD DE MÉXICO'},
#  {'CP': '16070',
#   'Calle': 'NUEVO LEÓN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN DIEGO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '984784',
#   'Latitud': '19.26219561',
#   'Longitud': '-99.10205492',
#   'Nombre': 'GIMNASIO NEW BODY',
#   'Num_Exterior': '36',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5541731184',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'XOCHIMILCO, Xochimilco, CIUDAD DE MÉXICO'},
#  {'CP': '07420',
#   'Calle': '310',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'NUEVA ATZACOALCO',
#   'Correo_e': 'MANUELMEDINAVAZA@HOTMAIL.COM',
#   'Estrato': '0 a 5 personas',
#   'Id': '767804',
#   'Latitud': '19.49645098',
#   'Longitud': '-99.08667714',
#   'Nombre': 'GIMNASIO NEW GYM',
#   'Num_Exterior': '464',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557373899',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD DE MÉXICO'},
#  {'CP': '06720',
#   'Calle': 'ARCOS DE BELÉN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'DOCTORES',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1030747',
#   'Latitud': '19.42607140',
#   'Longitud': '-99.15234479',
#   'Nombre': 'GIMNASIO NOMBRET',
#   'Num_Exterior': '44',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5557090622',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '01210',
#   'Calle': 'VASCO DE QUIROGA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PUEBLO SANTA FÉ',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '1016450',
#   'Latitud': '19.38302286',
#   'Longitud': '-99.23633598',
#   'Nombre': 'GIMNASIO NUEVA IMAGEN',
#   'Num_Exterior': '1545',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5552573580',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'ÁLVARO OBREGÓN, Álvaro Obregón, CIUDAD DE MÉXICO'},
#  {'CP': '06070',
#   'Calle': 'BUEN TONO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CENTRO',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '1041986',
#   'Latitud': '19.42729008',
#   'Longitud': '-99.14375192',
#   'Nombre': 'GIMNASIO NUEVO JORDAN',
#   'Num_Exterior': '36',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555100915',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '04600',
#   'Calle': 'SAN ISAURO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'PEDREGAL DE SANTA URSULA',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '1004974',
#   'Latitud': '19.30963793',
#   'Longitud': '-99.15636030',
#   'Nombre': 'GIMNASIO NUSAC GYM',
#   'Num_Exterior': '200',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5524570355',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'COYOACÁN, Coyoacán, CIUDAD DE MÉXICO'},
#  {'CP': '16090',
#   'Calle': 'CUAUHTÉMOC',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'SAN PEDRO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '994137',
#   'Latitud': '19.25881070',
#   'Longitud': '-99.10489181',
#   'Nombre': 'GIMNASIO OK GYM',
#   'Num_Exterior': '92',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556985661',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'XOCHIMILCO, Xochimilco, CIUDAD DE MÉXICO'},
#  {'CP': '06010',
#   'Calle': 'CENTRAL (LÁZARO CÁRDENAS)',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'CENTRO',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '980925',
#   'Latitud': '19.44258268',
#   'Longitud': '-99.13939113',
#   'Nombre': 'GIMNASIO OLIMPIA',
#   'Num_Exterior': '85',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555265865',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'EJE VIAL',
#   'Ubicacion': 'CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO'},
#  {'CP': '11870',
#   'Calle': 'HÉROES DE PADIERNA',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'TACUBAYA',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '737658',
#   'Latitud': '19.39760499',
#   'Longitud': '-99.18540711',
#   'Nombre': 'GIMNASIO OLIMPIA DOS',
#   'Num_Exterior': '305',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5552761427',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'MIGUEL HIDALGO, Miguel Hidalgo, CIUDAD DE MÉXICO'},
#  {'CP': '09040',
#   'Calle': 'CANAL DE TEZONTLE',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'EJIDOS DEL MORAL',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '744916',
#   'Latitud': '19.38311523',
#   'Longitud': '-99.08921183',
#   'Nombre': 'GIMNASIO OLIMPIC',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556941013',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  {'CP': '03560',
#   'Calle': 'CALZADA DE TLALPAN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'ALBERT',
#   'Correo_e': 'OLIMPOGYM1@HOTMAIL.COM',
#   'Estrato': '0 a 5 personas',
#   'Id': '973807',
#   'Latitud': '19.37019891',
#   'Longitud': '-99.14126343',
#   'Nombre': 'GIMNASIO OLÍMPO',
#   'Num_Exterior': '1306',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': 'WWW.OLIMPOGYM.COM',
#   'Telefono': '5555390427',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'AVENIDA',
#   'Ubicacion': 'BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO'},
#  {'CP': '10380',
#   'Calle': 'OLLIN',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'BARROS SIERRA',
#   'Correo_e': '',
#   'Estrato': '11 a 30 personas',
#   'Id': '1024153',
#   'Latitud': '19.31734665',
#   'Longitud': '-99.24776997',
#   'Nombre': 'GIMNASIO OLIMPYC',
#   'Num_Exterior': '2',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5555856818',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'LA MAGDALENA CONTRERAS, La Magdalena Contreras, CIUDAD DE MÉXICO'},
#  {'CP': '14240',
#   'Calle': 'AKIL',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'LOMAS DE PADIERNA',
#   'Correo_e': '',
#   'Estrato': '6 a 10 personas',
#   'Id': '913495',
#   'Latitud': '19.29030192',
#   'Longitud': '-99.22231557',
#   'Nombre': 'GIMNASIO OLIMPYGYM',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5526155410',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'TLALPAN, Tlalpan, CIUDAD DE MÉXICO'},
#  {'CP': '09300',
#   'Calle': 'JOSÉ LÓPEZ PORTILLO',
#   'Clase_actividad': 'Centros de acondicionamiento físico del sector privado',
#   'Colonia': 'GUADALUPE DEL MORAL',
#   'Correo_e': '',
#   'Estrato': '0 a 5 personas',
#   'Id': '783966',
#   'Latitud': '19.37018185',
#   'Longitud': '-99.07044949',
#   'Nombre': 'GIMNASIO OLYMPO',
#   'Num_Exterior': '0',
#   'Num_Interior': '',
#   'Razon_social': '',
#   'Sitio_internet': '',
#   'Telefono': '5556409617',
#   'Tipo': 'Fijo',
#   'Tipo_vialidad': 'CALLE',
#   'Ubicacion': 'IZTAPALAPA, Iztapalapa, CIUDAD DE MÉXICO'},
#  ...]

# %%
#Leemos el json como un DataFrame
gyms_cdmx = pd.DataFrame(x)
gyms_cdmx.head()
# Out:
#       CP                            Calle  \
# 0  11550                   ANATOLE FRANCE
# 1  07080                       CABO VERDE
# 2  06170                    ALFONSO REYES
# 3  03910                  INSURGENTES SUR
# 4  06100  3 SUR (AVENIDA BAJA CALIFORNIA)
#
#                                      Clase_actividad               Colonia  \
# 0  Centros de acondicionamiento físico del sector...       POLANCO REFORMA
# 1  Centros de acondicionamiento físico del sector...     GABRIEL HERNANDEZ
# 2  Centros de acondicionamiento físico del sector...     HIPÓDROMO CONDESA
# 3  Centros de acondicionamiento físico del sector...  SAN JOSÉ INSURGENTES
# 4  Centros de acondicionamiento físico del sector...             HIPÓDROMO
#
#                        Correo_e           Estrato       Id      Latitud  \
# 0  INFO@EVOLUTIONPILATES.COM.MX  11 a 30 personas   689998  19.43242053
# 1                                 6 a 10 personas   752673  19.49710213
# 2                                 6 a 10 personas   867230  19.41105369
# 3                                 6 a 10 personas  6785444  19.36301818
# 4                                 6 a 10 personas  6734479  19.40587201
#
#        Longitud                       Nombre Num_Exterior Num_Interior  \
# 0  -99.19751597  +EVOLUTION PILATES FITNNESS          129
# 1  -99.09947190                      4LMENTS           18
# 2  -99.18176246                       4U GYM            0
# 3  -99.18258457       8W BARRANCA DEL MUERTO         1647
# 4  -99.17085291                   8W CONDESA          261
#
#                    Razon_social               Sitio_internet    Telefono  \
# 0                                WWW.EVOLUTIONPILATES.COM.MX  5552818011
# 1
# 2                                               4UGYM.COM.MX  5552712042
# 3  OCHO SEMANAS I SAPI SA DE CV
# 4  OCHO SEMANAS I SAPI SA DE CV
#
#    Tipo Tipo_vialidad                                          Ubicacion
# 0  Fijo         CALLE   MIGUEL HIDALGO, Miguel Hidalgo, CIUDAD DE MÉXICO
# 1  Fijo         CALLE  GUSTAVO A. MADERO, Gustavo A. Madero, CIUDAD D...
# 2  Fijo         CALLE           CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO
# 3  Fijo       AVENIDA     BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO
# 4  Fijo      EJE VIAL           CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO

# %%
#Agregamos una columna de Entidad y Municipio, la cual va ser clave para el análisis posterior.
gyms_cdmx['Entidad'] =  ( 
                         gyms_cdmx['Ubicacion']
                         .str.split(',')
                         .str[2]
                         .str.replace('É', 'E')
                         )

# %%
#Agregamos una columna de Municipio
gyms_cdmx['Municipio'] =  ( 
                             gyms_cdmx['Ubicacion']
                             .str.split(',')
                             .str[0]
                             .str.replace('Á', 'A')
                             .str.replace('É', 'E')
                             .str.replace('Í', 'I')
                             .str.replace('Ó', 'O')
                             .str.replace('Ú', 'U')
                           )

# %% [markdown]
# *Segundo.* Ahora toca extraer la data de los **Censos Económicos 2014**, de forma tal que nos permita estimar el valor de las ventas en la CDMX del sector con SCIAN 713943. Para el análisis debemos tomar en cuenta tres puntos
#
# > -El objetivo es distribuir el valor total del indicador de ingresos de dicho sector para cada delegación, y posteriormente para cada establecimiento en función de su tamaño, medido por el estrato de personal ocupado.
#
# > -Para lograr lo anterior, debemos tomar 2 bases de datos de los CE, pero con información a difertente nivel de desagregación y estimar a partir de indices las proporciones para distribuir los valores de venta para cada establecimiento.
#
# > -Este modelo permiitrá visualizar la magnitud de las ventas de los establecimientos en función de su tamaño, no pretende ser un modelo que permita estimar ventas reales de un establecimiento en especifico. Toda vez que el objetivo específico del modelo es  dar un valor de referencia que facilite la toma de decisiones. Y así contar con una herramienta que permita reducir los costos asociados al trabajo de campo o sondeo que tradicionalmente hacen las grandes empresas para medir magnitudes de mercado a nivel de unidad económica. De esta forma hacemos accesible y al alcance de cualquier negocio  información económica a nivel geográfico y de establecimiento que optimice su toma de decisiones.

# %%
#La primera base de datos incluye infromación de los indicadores del censo a nivel de entidad y municipio.
#La base de datos se consulto en https://datos.gob.mx/busca/dataset/censos-economicos-2004-2014

ce_cdmx_mpio = (pd.read_csv(r'C:\Users\Erick\Documents\Mis Docs Erick\12_DATA ANALYS_GREENSHARK\Data_Analyst_Abril_2018\Proyecto final\data_input\ce_inegi_cdmx_mpio.csv',
                           low_memory=False))
ce_cdmx_mpio.head()
# Out:
#    clave_entidad entidad_federativa clave_municipio municipio  \
# 0              9   Ciudad de México                       NaN
# 1              9   Ciudad de México                       NaN
# 2              9   Ciudad de México                       NaN
# 3              9   Ciudad de México                       NaN
# 4              9   Ciudad de México                       NaN
#
#   clave_actividad_economica  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                        11
# 4                       11C
#
#                                  actividad_economica  anio_censal      UE  \
# 0                                      Total Estatal         2004  342475
# 1                                      Total Estatal         2009  382056
# 2                                      Total Estatal         2014  415481
# 3  Agricultura, cría y explotación de animales, a...         2014      17
# 4  Subsectores agrupados por el principio de conf...         2014      17
#
#          A111A        A121A     ...          P100B        Q000A       Q000B  \
# 0  1561323.953   602503.471     ...      52875.194   662462.535   60139.991
# 1  2340771.990  1007843.006     ...      74680.602  1033824.414  108487.327
# 2  2943782.839  1408762.132     ...      76848.574  2863865.216  148863.120
# 3       35.674       14.208     ...          0.000       16.804       1.498
# 4       35.674       14.208     ...          0.000       16.804       1.498
#
#         Q000C      Q000D        Q010A        Q020A       Q030A      Q400A  \
# 0   58660.153   9307.466   312569.605   224590.870   30504.568  34139.866
# 1  124965.327  18492.674   324698.716   520298.931   41805.795  52331.476
# 2  121574.916  28071.332  1012005.945  1449208.900  162720.035  65235.691
# 3       0.096      0.000        3.273        9.300       1.120      0.389
# 4       0.096      0.000        3.273        9.300       1.120      0.389
#
#         Q900A
# 0   60657.626
# 1   94689.496
# 2  174694.645
# 3       2.722
# 4       2.722
#
# [5 rows x 105 columns]

# %%
#Me quedo solo con los campos de interés

ce_cdmx_mpio = ce_cdmx_mpio[['anio_censal',
                             'clave_entidad',
                             'entidad_federativa',
                             'clave_municipio',
                             'municipio',
                             'clave_actividad_economica',
                             'actividad_economica',
                             'UE',
                             'H001A',#personal_ocupado_total
                             'H001B',#personal_ocupado_hom
                             'H001C',#personal_ocupado_muj
                             'K000A',#Total_ingreso
                             'A700A',#Ingresos_bys
                             'J000A',#Remuneraciones/salario
                             'M000A',#Gasto_ingreso
                             'A800A']]#Gasto_bys
ce_cdmx_mpio.head(5)
# Out:
#    anio_censal  clave_entidad entidad_federativa clave_municipio municipio  \
# 0         2004              9   Ciudad de México                       NaN
# 1         2009              9   Ciudad de México                       NaN
# 2         2014              9   Ciudad de México                       NaN
# 3         2014              9   Ciudad de México                       NaN
# 4         2014              9   Ciudad de México                       NaN
#
#   clave_actividad_economica  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                        11
# 4                       11C
#
#                                  actividad_economica      UE    H001A  \
# 0                                      Total Estatal  342475  2842874
# 1                                      Total Estatal  382056  3299325
# 2                                      Total Estatal  415481  3603572
# 3  Agricultura, cría y explotación de animales, a...      17      125
# 4  Subsectores agrupados por el principio de conf...      17      125
#
#      H001B    H001C        K000A        A700A       J000A        M000A  \
# 0  1762761  1080113  1113201.409  1700873.545  246760.939  1573471.093
# 1  1969647  1329678  2253628.476  4017057.643  277277.237  2732374.045
# 2  2105450  1498122  2049042.824  3088556.059  380314.987  2828079.281
# 3       83       42       14.208       14.558       6.622       35.592
# 4       83       42       14.208       14.558       6.622       35.592
#
#          A800A
# 0  2514844.957
# 1  4122882.015
# 2  4215502.308
# 3       36.116
# 4       36.116

# %%
#Vamos a filtrar solo el sector que nos interesa estudiar y lo guardamos en un nuevo data frame

scian_sector = '713943'

ce_cdmx_mpio_gym = ce_cdmx_mpio[ce_cdmx_mpio['clave_actividad_economica'] == scian_sector]

# %%
#Cargamos el diccionario de datos para poder nombrar las columnas de los indicadores
ce_cdmx_mpio_dict = (pd.read_csv(r'C:\Users\Erick\Documents\Mis Docs Erick\12_DATA ANALYS_GREENSHARK\Data_Analyst_Abril_2018\Proyecto final\data_input\ce_inegi_cdmx_mpio_dict.csv',
                           low_memory=False))

# %%
#vamos a quedarnos solo con los campos que nos importan.
#primero agregamos una columna que solo contenga el nombre del indicador del CE.

ce_cdmx_mpio_dict['Indicador'] =  ( 
                                     ce_cdmx_mpio_dict['Definición']
                                     .str.split('.')
                                     .str[0]
                                     .str.replace('Á', 'A')
                                     .str.replace('É', 'E')
                                     .str.replace('Í', 'I')
                                     .str.replace('Ó', 'O')
                                     .str.replace('Ú', 'U')
                                     .str.replace('á', 'a')
                                     .str.replace('é', 'e')
                                     .str.replace('í', 'i')
                                     .str.replace('ó', 'o')
                                     .str.replace('ú', 'u')
                                   )

# %%
#Modificamos el nombre de los campos de interes del diccionario

ce_cdmx_mpio_dict = ce_cdmx_mpio_dict.rename(columns = {
                                    'Nombre del Atributo en CSV' : 'nombre_campo',
                                    'Tipo de dato' : 'tipo_dato',
                                    'Longitud' : 'longitud',
                                    'Indicador' : 'nombre_indicador'
                                    })

# %%
ce_cdmx_mpio_dict = ce_cdmx_mpio_dict[[ 'nombre_campo',
                                        'nombre_indicador',
                                        'tipo_dato',
                                        'longitud']] 

ce_cdmx_mpio_dict.head()
# Out:
#                 nombre_campo           nombre_indicador     tipo_dato  \
# 0              clave_entidad           Clave de entidad  alfanumérico
# 1         entidad_federativa         Entidad federativa  alfanumérico
# 2            clave_municipio            Clave municipio  alfanumérico
# 3                  municipio                  Municipio  alfanumérico
# 4  clave_actividad_economica  Clave actividad economica  alfanumérico
#
#    longitud
# 0         2
# 1        60
# 2         5
# 3       100
# 4        25

# %%
#Dejo el diccionario de datos en formato de diccionario, en este formato ya es sencillo asignar el nombre a los campos 
#codificados.
dict_ce = dict(zip(ce_cdmx_mpio_dict['nombre_campo'], ce_cdmx_mpio_dict['nombre_indicador']))

# %% [markdown]
# La seunda base de datos que vamos a necesitar es igualmente del CE 2014, pero con diferente desagregación.
# Dicha BD contiene información a nivel de entidad federativa y estrato de personal ocupado. Desafortunadamente,
# por temas de confidencialidad no se encontrará data disponible a este nivel pero con rango de personal ocupado, de lo contrario este ejercicio no sería necesario.

# %%
#Aquí se puede enconrar la data por tamaño de la UE http://www.beta.inegi.org.mx/app/descarga/?p=1664&ag=00&da=1
#Aquí se puede descargar la data por estrato, que es la más útil, para estimar el estrato a nivel de municipio http://www.beta.inegi.org.mx/proyectos/ce/2014/

ce_cdmx_espo = (pd.read_excel(r'C:\Users\Erick\Documents\Mis Docs Erick\12_DATA ANALYS_GREENSHARK\Data_Analyst_Abril_2018\Proyecto final\data_input\ce_inegi_cdmx_espo.xlsx',
                             sheet_name = 'Cuadro gedfce14_02',
                             header = 9))

# %%
ce_cdmx_espo.head()
# Out:
#   ENTIDAD FEDERATIVA\n SECTOR SUBSECTOR RAMA CLASE  \
# 0                09 DF    NaN       NaN  NaN   NaN
# 1                09 DF    NaN       NaN  NaN   NaN
# 2                09 DF    NaN       NaN  NaN   NaN
# 3                09 DF    NaN       NaN  NaN   NaN
# 4                09 DF    NaN       NaN  NaN   NaN
#
#   TAMAÑO DE LA \nUNIDAD ECONÓMICA                    DENOMINACIÓN  \
# 0                             NaN                Distrito Federal
# 1                   01) Hasta   2               Hasta 2  personas
# 2     02) De        3  a        5  De      3  a       5  personas
# 3      03) De        6  a      10   De      6  a     10  personas
# 4       04) De      11  a      15    De    11  a     15  personas
#
#   UNIDADES ECONÓMICAS  TOTAL-PERSONAL OCUPADO  \
# 0              415481               3603572.0
# 1              279226                397831.0
# 2               82863                298272.0
# 3               25459                189562.0
# 4                8202                105704.0
#
#    TOTAL-PERSONAL OCUPADO DEPENDIENTE DE LA RAZÓN SOCIAL  \
# 0                                          2805367.0
# 1                                           391452.0
# 2                                           280702.0
# 3                                           162418.0
# 4                                            84937.0
#
#                 ...                 REMUNERACIONES  \
# 0               ...                     380314.987
# 1               ...                       2920.973
# 2               ...                       7086.084
# 3               ...                       8465.697
# 4               ...                       5425.570
#
#    GASTOS \nPOR CONSUMO \nDE BIENES\nY SERVICIOS  \
# 0                                    2049042.824
# 1                                      75874.439
# 2                                      76811.510
# 3                                      80104.963
# 4                                      56826.794
#
#    INGRESOS \nPOR SUMINISTRO \nDE BIENES \nY SERVICIOS  \
# 0                                        2828079.281
# 1                                          93214.930
# 2                                          99756.358
# 3                                         122964.529
# 4                                          75089.182
#
#    PRODUCCIÓN \nBRUTA TOTAL  CONSUMO INTERMEDIO  \
# 0               2943782.839         1408762.132
# 1                148605.383           41260.866
# 2                 95394.465           40720.893
# 3                 80408.738           33928.979
# 4                 64676.069           23252.103
#
#    VALOR AGREGADO CENSAL BRUTO                \
# 0                                1535020.707
# 1                                 107344.517
# 2                                  54673.572
# 3                                  46479.759
# 4                                  41423.966
#
#    FORMACIÓN BRUTA \nDE CAPITAL FIJO  VARIACIÓN TOTAL\nDE EXISTENCIAS  \
# 0                          93503.584                        11074.824
# 1                           1080.741                          371.928
# 2                            883.729                          219.350
# 3                           1170.775                          448.859
# 4                            948.358                          286.096
#
#    ACTIVOS FIJOS  DEPRECIACIÓN \nDE ACTIVOS FIJOS
# 0    2863865.216                     148863.11988
# 1      29560.585                       2513.13957
# 2      22768.164                       2037.73923
# 3      25729.248                       2604.59051
# 4      15411.253                       1510.04847
#
# [5 rows x 23 columns]

# %%
#Renombramos columnas, ya que contienen muchos saltos de linea
ce_cdmx_espo = ce_cdmx_espo.rename(columns = {
                                              'ENTIDAD FEDERATIVA\n' : 'entidad_federativa0',
                                              'SECTOR' : 'sector',                                                    
                                              'SUBSECTOR' : 'subsector',
                                              'RAMA' : 'rama',
                                              'CLASE' : 'clase',
                                              'DENOMINACIÓN' : 'estrato',
                                              'TAMAÑO DE LA \nUNIDAD ECONÓMICA' : 'tamanio_ue',
                                              'UNIDADES ECONÓMICAS' : 'UE',
                                              'TOTAL-PERSONAL OCUPADO' : 'H001A',
                                              'TOTAL-PERSONAL OCUPADO DEPENDIENTE DE LA RAZÓN SOCIAL' : 'H000A',
                                              'PERSONAL \nOCUPADO REMUNERADO' : 'H010A',
                                              'PERSONAL OCUPADO-PROPIETARIOS, FAMILIARES Y OTROS TRABAJADORES NO REMUNERADOS' : 'H020A',
                                              'PERSONAL OCUPADO-NO DEPENDIENTE \nDE LA RAZÓN SOCIAL' : 'I000A',
                                              'REMUNERACIONES' : 'J000A',
                                              'GASTOS \nPOR CONSUMO \nDE BIENES\nY SERVICIOS' : 'K000A',
                                              'PRODUCCIÓN \nBRUTA TOTAL' : 'A111A',
                                              'CONSUMO INTERMEDIO' : 'A121A',
                                              'VALOR AGREGADO CENSAL BRUTO              ' : 'A131A',
                                              'FORMACIÓN BRUTA \nDE CAPITAL FIJO' : 'A221A',
                                              'VARIACIÓN TOTAL\nDE EXISTENCIAS' : 'P000C',
                                              'ACTIVOS FIJOS' : 'O020A',
                                              'DEPRECIACIÓN \nDE ACTIVOS FIJOS' : 'Q000B',
                                              'INGRESOS \nPOR SUMINISTRO \nDE BIENES \nY SERVICIOS': 'M000A' 
                                             })
ce_cdmx_espo.head(50)
# Out:
#    entidad_federativa0     sector      subsector       rama         clase  \
# 0                09 DF        NaN            NaN        NaN           NaN
# 1                09 DF        NaN            NaN        NaN           NaN
# 2                09 DF        NaN            NaN        NaN           NaN
# 3                09 DF        NaN            NaN        NaN           NaN
# 4                09 DF        NaN            NaN        NaN           NaN
# 5                09 DF        NaN            NaN        NaN           NaN
# 6                09 DF        NaN            NaN        NaN           NaN
# 7                09 DF        NaN            NaN        NaN           NaN
# 8                09 DF        NaN            NaN        NaN           NaN
# 9                09 DF        NaN            NaN        NaN           NaN
# 10               09 DF        NaN            NaN        NaN           NaN
# 11               09 DF        NaN            NaN        NaN           NaN
# 12               09 DF        NaN            NaN        NaN           NaN
# 13               09 DF  Sector 11            NaN        NaN           NaN
# 14               09 DF  Sector 11            NaN        NaN           NaN
# 15               09 DF  Sector 11            NaN        NaN           NaN
# 16               09 DF  Sector 11            NaN        NaN           NaN
# 17               09 DF  Sector 11            NaN        NaN           NaN
# 18               09 DF  Sector 11            NaN        NaN           NaN
# 19               09 DF  Sector 11            NaN        NaN           NaN
# 20               09 DF  Sector 11  Subsector 112        NaN           NaN
# 21               09 DF  Sector 11  Subsector 112        NaN           NaN
# 22               09 DF  Sector 11  Subsector 112  Rama 1125           NaN
# 23               09 DF  Sector 11  Subsector 112  Rama 1125           NaN
# 24               09 DF  Sector 11  Subsector 112  Rama 1125  Clase 112512
# 25               09 DF  Sector 11  Subsector 112  Rama 1125  Clase 112512
# 26               09 DF  Sector 11  Subsector 115        NaN           NaN
# 27               09 DF  Sector 11  Subsector 115        NaN           NaN
# 28               09 DF  Sector 11  Subsector 115        NaN           NaN
# 29               09 DF  Sector 11  Subsector 115        NaN           NaN
# 30               09 DF  Sector 11  Subsector 115        NaN           NaN
# 31               09 DF  Sector 11  Subsector 115        NaN           NaN
# 32               09 DF  Sector 11  Subsector 115        NaN           NaN
# 33               09 DF  Sector 11  Subsector 115  Rama 1151           NaN
# 34               09 DF  Sector 11  Subsector 115  Rama 1151           NaN
# 35               09 DF  Sector 11  Subsector 115  Rama 1151           NaN
# 36               09 DF  Sector 11  Subsector 115  Rama 1151           NaN
# 37               09 DF  Sector 11  Subsector 115  Rama 1151           NaN
# 38               09 DF  Sector 11  Subsector 115  Rama 1151           NaN
# 39               09 DF  Sector 11  Subsector 115  Rama 1151  Clase 115113
# 40               09 DF  Sector 11  Subsector 115  Rama 1151  Clase 115113
# 41               09 DF  Sector 11  Subsector 115  Rama 1151  Clase 115113
# 42               09 DF  Sector 11  Subsector 115  Rama 1151  Clase 115113
# 43               09 DF  Sector 11  Subsector 115  Rama 1151  Clase 115113
# 44               09 DF  Sector 11  Subsector 115  Rama 1151  Clase 115119
# 45               09 DF  Sector 11  Subsector 115  Rama 1151  Clase 115119
# 46               09 DF  Sector 11  Subsector 115  Rama 1152           NaN
# 47               09 DF  Sector 11  Subsector 115  Rama 1152           NaN
# 48               09 DF  Sector 11  Subsector 115  Rama 1152           NaN
# 49               09 DF  Sector 11  Subsector 115  Rama 1152           NaN
#
#                      tamanio_ue  \
# 0                           NaN
# 1                 01) Hasta   2
# 2   02) De        3  a        5
# 3    03) De        6  a      10
# 4     04) De      11  a      15
# 5     05) De      16  a      20
# 6     06) De      21  a      30
# 7     07) De      31  a      50
# 8      08) De      51  a    100
# 9       09) De    101  a    250
# 10      10) De    251  a    500
# 11       11) De    501  a 1 000
# 12        12) De 1 001  y   más
# 13                          NaN
# 14                01) Hasta   2
# 15  02) De        3  a        5
# 16   03) De        6  a      10
# 17    04) De      11  a      15
# 18    05) De      16  a      20
# 19    06) De      21  a      30
# 20                          NaN
# 21  02) De        3  a        5
# 22                          NaN
# 23  02) De        3  a        5
# 24                          NaN
# 25  02) De        3  a        5
# 26                          NaN
# 27                01) Hasta   2
# 28  02) De        3  a        5
# 29   03) De        6  a      10
# 30    04) De      11  a      15
# 31    05) De      16  a      20
# 32    06) De      21  a      30
# 33                          NaN
# 34                01) Hasta   2
# 35  02) De        3  a        5
# 36   03) De        6  a      10
# 37    05) De      16  a      20
# 38    06) De      21  a      30
# 39                          NaN
# 40                01) Hasta   2
# 41  02) De        3  a        5
# 42   03) De        6  a      10
# 43    05) De      16  a      20
# 44                          NaN
# 45    06) De      21  a      30
# 46                          NaN
# 47                01) Hasta   2
# 48   03) De        6  a      10
# 49    04) De      11  a      15
#
#                                               estrato      UE      H001A  \
# 0                                    Distrito Federal  415481  3603572.0
# 1                                   Hasta 2  personas  279226   397831.0
# 2                      De      3  a       5  personas   82863   298272.0
# 3                       De      6  a     10  personas   25459   189562.0
# 4                        De    11  a     15  personas    8202   105704.0
# 5                        De    16  a     20  personas    4381    79471.0
# 6                        De    21  a     30  personas    4618   116343.0
# 7                        De    31  a     50  personas    4366   173915.0
# 8                         De    51  a   100  personas    2922   207243.0
# 9                          De  101  a   250  personas    2143   331670.0
# 10                         De  251  a   500  personas     749   258108.0
# 11                          De  501  a 1 000 personas     302   215674.0
# 12                           De 1 001 y  más personas     250  1229779.0
# 13  Sector 11 Agricultura, cría y explotación de a...      17      125.0
# 14                                  Hasta 2  personas       6       10.0
# 15                     De      3  a       5  personas       *       12.0
# 16                      De      6  a     10  personas       5       45.0
# 17                       De    11  a     15  personas       *       14.0
# 18                       De    16  a     20  personas       *       18.0
# 19                       De    21  a     30  personas       *       26.0
# 20       Subsector 112 Cría y explotación de animales       *        7.0
# 21                     De      3  a       5  personas       *        7.0
# 22                              Rama 1125 Acuicultura       *        7.0
# 23                     De      3  a       5  personas       *        7.0
# 24  Clase 112512 Piscicultura y otra acuicultura, ...       *        7.0
# 25                     De      3  a       5  personas       *        7.0
# 26  Subsector 115 Servicios relacionados con las a...       *      118.0
# 27                                  Hasta 2  personas       *       10.0
# 28                     De      3  a       5  personas       *        5.0
# 29                      De      6  a     10  personas       *       45.0
# 30                       De    11  a     15  personas       *       14.0
# 31                       De    16  a     20  personas       *       18.0
# 32                       De    21  a     30  personas       *       26.0
# 33  Rama 1151 Servicios relacionados con la agricu...       *       82.0
# 34                                  Hasta 2  personas       *        8.0
# 35                     De      3  a       5  personas       *        5.0
# 36                      De      6  a     10  personas       *       25.0
# 37                       De    16  a     20  personas       *       18.0
# 38                       De    21  a     30  personas       *       26.0
# 39      Clase 115113 Beneficio de productos agrícolas       *       56.0
# 40                                  Hasta 2  personas       *        8.0
# 41                     De      3  a       5  personas       *        5.0
# 42                      De      6  a     10  personas       *       25.0
# 43                       De    16  a     20  personas       *       18.0
# 44  Clase 115119 Otros servicios relacionados con ...       *       26.0
# 45                       De    21  a     30  personas       *       26.0
# 46  Rama 1152 Servicios relacionados con la cría y...       *       36.0
# 47                                  Hasta 2  personas       *        2.0
# 48                      De      6  a     10  personas       *       20.0
# 49                       De    11  a     15  personas       *       14.0
#
#         H000A      ...            J000A        K000A        M000A  \
# 0   2805367.0      ...       380314.987  2049042.824  2828079.281
# 1    391452.0      ...         2920.973    75874.439    93214.930
# 2    280702.0      ...         7086.084    76811.510    99756.358
# 3    162418.0      ...         8465.697    80104.963   122964.529
# 4     84937.0      ...         5425.570    56826.794    75089.182
# 5     63099.0      ...         4430.143    43735.347    59617.060
# 6     92083.0      ...         6943.789    78953.052    92557.529
# 7    131136.0      ...        11611.492   124448.312   177489.214
# 8    133891.0      ...        15789.495   199187.453   261959.993
# 9    211073.0      ...        28873.523   278617.217   352925.602
# 10   159913.0      ...        29018.304   183896.610   255573.594
# 11   145769.0      ...        26994.090   116897.918   188653.199
# 12   948894.0      ...       232755.827   733689.209  1048278.091
# 13       99.0      ...            6.622       14.208       35.592
# 14       10.0      ...            0.869        3.077        4.465
# 15       12.0      ...            0.701        1.771        2.860
# 16       45.0      ...            3.635        3.477       12.827
# 17       14.0      ...            1.131        0.652        1.920
# 18       18.0      ...            0.286        2.640        5.520
# 19        0.0      ...            0.000        2.591        8.000
# 20        7.0      ...            0.248        1.224        1.540
# 21        7.0      ...            0.248        1.224        1.540
# 22        7.0      ...            0.248        1.224        1.540
# 23        7.0      ...            0.248        1.224        1.540
# 24        7.0      ...            0.248        1.224        1.540
# 25        7.0      ...            0.248        1.224        1.540
# 26       92.0      ...            6.374       12.984       34.052
# 27       10.0      ...            0.869        3.077        4.465
# 28        5.0      ...            0.453        0.547        1.320
# 29       45.0      ...            3.635        3.477       12.827
# 30       14.0      ...            1.131        0.652        1.920
# 31       18.0      ...            0.286        2.640        5.520
# 32        0.0      ...            0.000        2.591        8.000
# 33       56.0      ...            2.535       11.518       25.815
# 34        8.0      ...            0.869        3.039        4.399
# 35        5.0      ...            0.453        0.547        1.320
# 36       25.0      ...            0.927        2.701        6.576
# 37       18.0      ...            0.286        2.640        5.520
# 38        0.0      ...            0.000        2.591        8.000
# 39       56.0      ...            2.535        8.927       17.815
# 40        8.0      ...            0.869        3.039        4.399
# 41        5.0      ...            0.453        0.547        1.320
# 42       25.0      ...            0.927        2.701        6.576
# 43       18.0      ...            0.286        2.640        5.520
# 44        0.0      ...            0.000        2.591        8.000
# 45        0.0      ...            0.000        2.591        8.000
# 46       36.0      ...            3.839        1.466        8.237
# 47        2.0      ...            0.000        0.038        0.066
# 48       20.0      ...            2.708        0.776        6.251
# 49       14.0      ...            1.131        0.652        1.920
#
#           A111A        A121A        A131A      A221A      P000C        O020A  \
# 0   2943782.839  1408762.132  1535020.707  93503.584  11074.824  2863865.216
# 1    148605.383    41260.866   107344.517   1080.741    371.928    29560.585
# 2     95394.465    40720.893    54673.572    883.729    219.350    22768.164
# 3     80408.738    33928.979    46479.759   1170.775    448.859    25729.248
# 4     64676.069    23252.103    41423.966    948.358    286.096    15411.253
# 5     32467.716    17684.057    14783.659    488.231    -70.697    13015.139
# 6     52318.736    37957.294    14361.442   1271.713    -49.427    27018.197
# 7    116954.906    61875.786    55079.120   3469.469     34.724    64436.659
# 8    168313.062    98295.680    70017.382   4646.195   -252.577    98966.196
# 9    231107.408   135177.500    95929.908   4095.021   -568.487    81448.423
# 10   221694.029   126519.545    95174.484   3340.339    213.819    65081.385
# 11   190057.172    95329.436    94727.736   2901.699   -433.109    50007.698
# 12  1541785.155   696759.993   845025.162  69207.314  10874.345  2370422.269
# 13       35.674       14.208       21.466      0.096      0.002       16.804
# 14        4.465        3.077        1.388      0.000      0.000        3.278
# 15        2.860        1.771        1.089      0.000      0.000        1.743
# 16       12.849        3.477        9.372      0.022      0.002        4.291
# 17        1.980        0.652        1.328      0.060      0.000        4.560
# 18        5.520        2.640        2.880      0.000      0.000        0.082
# 19        8.000        2.591        5.409      0.014      0.000        2.850
# 20        1.540        1.224        0.316      0.000      0.000        1.615
# 21        1.540        1.224        0.316      0.000      0.000        1.615
# 22        1.540        1.224        0.316      0.000      0.000        1.615
# 23        1.540        1.224        0.316      0.000      0.000        1.615
# 24        1.540        1.224        0.316      0.000      0.000        1.615
# 25        1.540        1.224        0.316      0.000      0.000        1.615
# 26       34.134       12.984       21.150      0.096      0.002       15.189
# 27        4.465        3.077        1.388      0.000      0.000        3.278
# 28        1.320        0.547        0.773      0.000      0.000        0.128
# 29       12.849        3.477        9.372      0.022      0.002        4.291
# 30        1.980        0.652        1.328      0.060      0.000        4.560
# 31        5.520        2.640        2.880      0.000      0.000        0.082
# 32        8.000        2.591        5.409      0.014      0.000        2.850
# 33       25.837       11.518       14.319      0.036      0.002        8.531
# 34        4.399        3.039        1.360      0.000      0.000        2.530
# 35        1.320        0.547        0.773      0.000      0.000        0.128
# 36        6.598        2.701        3.897      0.022      0.002        2.941
# 37        5.520        2.640        2.880      0.000      0.000        0.082
# 38        8.000        2.591        5.409      0.014      0.000        2.850
# 39       17.837        8.927        8.910      0.022      0.002        5.681
# 40        4.399        3.039        1.360      0.000      0.000        2.530
# 41        1.320        0.547        0.773      0.000      0.000        0.128
# 42        6.598        2.701        3.897      0.022      0.002        2.941
# 43        5.520        2.640        2.880      0.000      0.000        0.082
# 44        8.000        2.591        5.409      0.014      0.000        2.850
# 45        8.000        2.591        5.409      0.014      0.000        2.850
# 46        8.297        1.466        6.831      0.060      0.000        6.658
# 47        0.066        0.038        0.028      0.000      0.000        0.748
# 48        6.251        0.776        5.475      0.000      0.000        1.350
# 49        1.980        0.652        1.328      0.060      0.000        4.560
#
#            Q000B
# 0   148863.11988
# 1     2513.13957
# 2     2037.73923
# 3     2604.59051
# 4     1510.04847
# 5     1482.79905
# 6     3364.04799
# 7     6838.97955
# 8     6052.78576
# 9     6649.77840
# 10    5498.88111
# 11    4366.76995
# 12  105943.56029
# 13       1.49769
# 14       0.17880
# 15       0.21314
# 16       0.41315
# 17       0.32750
# 18       0.02260
# 19       0.34250
# 20       0.18200
# 21       0.18200
# 22       0.18200
# 23       0.18200
# 24       0.18200
# 25       0.18200
# 26       1.31569
# 27       0.17880
# 28       0.03114
# 29       0.41315
# 30       0.32750
# 31       0.02260
# 32       0.34250
# 33       0.84779
# 34       0.13300
# 35       0.03114
# 36       0.31855
# 37       0.02260
# 38       0.34250
# 39       0.50529
# 40       0.13300
# 41       0.03114
# 42       0.31855
# 43       0.02260
# 44       0.34250
# 45       0.34250
# 46       0.46790
# 47       0.04580
# 48       0.09460
# 49       0.32750
#
# [50 rows x 23 columns]

# %%
#Se tiene que agregar las columnas: anio_censal, clave_entidad, entidad_federativa, 
#clave_actividad_economica, actividad_economica. Para poder realizar los cruces pertinentes.

ce_cdmx_espo['anio_censal'] =  2014

ce_cdmx_espo['clave_entidad'] =  ( 
                                     ce_cdmx_espo['entidad_federativa0']
                                     .str.split('\s')
                                     .str[0]
                                   )

ce_cdmx_espo['entidad_federativa'] =  ( 
                                         ce_cdmx_espo['entidad_federativa0']
                                         .str.split('\s')
                                         .str[1]
                                       )


ce_cdmx_espo.head(2)
# Out:
#   entidad_federativa0 sector subsector rama clase     tamanio_ue  \
# 0               09 DF    NaN       NaN  NaN   NaN            NaN
# 1               09 DF    NaN       NaN  NaN   NaN  01) Hasta   2
#
#              estrato      UE      H001A      H000A         ...          \
# 0   Distrito Federal  415481  3603572.0  2805367.0         ...
# 1  Hasta 2  personas  279226   397831.0   391452.0         ...
#
#          A111A        A121A        A131A      A221A      P000C        O020A  \
# 0  2943782.839  1408762.132  1535020.707  93503.584  11074.824  2863865.216
# 1   148605.383    41260.866   107344.517   1080.741    371.928    29560.585
#
#           Q000B  anio_censal  clave_entidad  entidad_federativa
# 0  148863.11988         2014             09                  DF
# 1    2513.13957         2014             09                  DF
#
# [2 rows x 26 columns]

# %% [markdown]
# #### Importando los datos a MySql
#
# Una vez explicado y preparados todos los insumos de data para el modelo, es hora de indexar cada fuente de datos en MySQL.
# En donde haremos un poco más de limpieza de datos para que sean consumidas por el modelo de manera eficiente.

# %%
import MySQLdb

# %%
#Conexion a la base de datos de mysql proyecto_final

mysql_conexion =  MySQLdb.connect(host = 'localhost',
                                 port = 3306,
                                 user = 'root',
                                 passwd = 'Adriff22',
                                 db = 'proyecto_final')

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqldb://root:"+'Adriff22'+"@localhost/proyecto_final")

# %% [markdown]
# Ahora vamos a importar a mysql los siguientes data frames:
# > -DENUE con iformación de los establecimientos en la CDMX del sector de gimnasios: **'gyms_cdmx'**
#
# > -Censos Económicos 2014, con datos a nivel de municipio en la CDMX y del sector 713943 : **'ce_cdmx_mpio_gym'**
#
# > -Diccionario de datos de los Censos Económicos 2014: **'ce_cdmx_mpio_dict'**
#
# > -Censos Económicos 2014, con datos a nivel de estrato de personal ocupado en la CDMX: **'ce_cdmx_espo'**

# %%
gyms_cdmx.to_sql("dnue_cdmx_713943", con = engine, if_exists = 'replace', index = True)
# Out:
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py:507: Warning: (1366, "Incorrect string value: '\\xE9xic' for column 'VARIABLE_VALUE' at row 518")
#   cursor.execute(statement, parameters)
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py:507: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, which will be replaced by UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   cursor.execute(statement, parameters)

# %%
ce_cdmx_mpio_gym.to_sql("ce_cdmx_mpio_713943", con = engine, if_exists = 'replace', index = True)
# Out:
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py:507: Warning: (1366, "Incorrect string value: '\\xE9xic' for column 'VARIABLE_VALUE' at row 518")
#   cursor.execute(statement, parameters)
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py:507: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, which will be replaced by UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   cursor.execute(statement, parameters)

# %%
ce_cdmx_mpio_dict.to_sql("ce_cdmx_mpio_dict", con = engine, if_exists = 'replace', index = True)

# %%
ce_cdmx_espo.to_sql("ce_cdmx_espo", con = engine, if_exists = 'replace', index = True)
